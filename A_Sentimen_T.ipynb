# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Import Packages

# %% [markdown]
# Packages yang digunakan untuk mengambil data dari Twitter API dapat menggunakan packages tweepy. Tweepy adalah packages open source yang dapat memberikan kenyamanan untuk mengakses API Twitter dengan Python. Tweepy menyertakan satu set kelas dan metode yang mewakili model Twitter dan titik akhir API, dan secara transparan menangani berbagai detail implementasi, seperti: encoding dan decoding data.

# %%
import tweepy as tw
import re
import pandas as pd
from textblob import TextBlob

# %% [markdown]
# # Authenticate the Twitter API with Tweepy

# %% [markdown]
# Sebelum autentikasi Twitter API, kita perlu membuat persetujuan akun developer Twitter untuk mendapatkan kode yang diperlukan untuk autentikasi akun kita. Setelah akun disetujui, kita akan mendapatkan kredensial Twitter API. Kita perlu kode pada api_key, api_key_secret, access_token, dan access_token_secret agar dapat menghubungkan Twitter API menggunakan Tweepy.

# %%
api_key = # Input API Key Disini
api_key_secret = # Input API Key Secret Disini
access_token = # Input Access Token Disini
access_token_secret = # Input Access Token Secret Disini

# %%
auth = tw.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth)

# %% [markdown]
# ## Searching Data Twitter for Sentiment Analysis

# %%
search_term = ("Jakarta")
tweet_search = api.search(q=search_term, lang="id",count=200, tweet_mode = "extended")

# %%
data_search =[]

for teks in tweet_search:
    teks_properties= {}
    teks_properties["Tanggal"]=teks.created_at
    teks_properties["Pengguna"]=teks.user.screen_name
    teks_clean = ' '.join(re.sub("(@[A-Za-z0-9]+)"," ",teks.full_text).split())
    teks_properties["Tweet"]= teks_clean

    analysis = TextBlob(teks_clean)
    if analysis.sentiment.polarity > 0.0:
      teks_properties["Sentimen"]= 'Positif'
    elif analysis.sentiment.polarity == 0.0:
      teks_properties["Sentimen"]= 'Netral'
    else:
      teks_properties["Sentimen"]= 'Negatif'

    if teks.retweet_count > 0:
        if teks_properties not in data_search:
            data_search.append(teks_properties)
    else:
        data_search.append(teks_properties)
        
data_search
# Out:
# [{'Pengguna': 'rumah_jualbeli',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 54, 47),
#   'Tweet': 'TERJANGKAU, Hubungi 0812-1244-2489, Kavling Tanah Dijual Murah Di Kavling Desa Wisata Kebun Buah Saung Estetik Dekat Jakarta https://t.co/gdKc5cgfn6'},
#  {'Pengguna': 'salbi__',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 54, 42),
#   'Tweet': 'akwowakoawkaow kos gawe di jakarta wae'},
#  {'Pengguna': 'dwijlynt',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 54, 26),
#   'Tweet': 'Damage nya ga parah banget nih nder , take all ada potongan harga 5k/ea. Cek condi di dm^^ 📍Jakarta 🍊Freong ✅Keep event ✅Freebies ✅inc packing /sdh termasuk packing https://t.co/lfZAWrkn6u'},
#  {'Pengguna': 'setyawarni123',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 54, 26),
#   'Tweet': 'RT : Goodbener mengajak kita semua warga DKI Jakarta untuk menggapai keberkahan Allah dengan serentak membaca Alq…'},
#  {'Pengguna': 'T_Irham',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 54, 20),
#   'Tweet': '10# Berikut delapan dukungan yang disampaikan Anies dibutuhkan Jakarta dari pemerintah pusat yakni:'},
#  {'Pengguna': 'Zulkarn92072924',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 54, 16),
#   'Tweet': 'RT : PEJABAT JIKA SUDAH TERCAP PEMBOHONG PLEH RAKYAT NYA ...APALAGI YG AKAN KALIAN LAKUKAN❓ AGAR TAK LEBIH MEMALUKAN LAGI .…'},
#  {'Pengguna': 'asyur77',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3,

#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 52, 34),
#   'Tweet': 'hallo ka, silahkan akses kembali ya (byDA)'},
#  {'Pengguna': 'pwtupdate',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 52, 28),
#   'Tweet': 'RT : Semakin dekat dengan Anda untuk memberikan layanan purna jual, Fingerspot hadir diberbagai lokasi : ✅Jakarta ✅Bandung…'},
#  {'Pengguna': 'kalpiyanti',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 52, 23),
#   'Tweet': '_Jakarta Nim aku, 030898578'},
#  {'Pengguna': 'dearyyongie',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 52, 17),
#   'Tweet': 'RT : Aamiin,salam satu aspal mas. Dari driver jakarta https://t.co/Kp5k1dCpgF'},
#  {'Pengguna': 'semangatyach',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 52, 15),
#   'Tweet': 'RT : 🚨BREAKING!🚨 PSSI, Barito, Persib dan David da Silva, resmi digugat di Pengadilan Negeri Jakarta Pusat atas dugaan sepak b…'},
#  {'Pengguna': 'UT_Jakarta',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 52, 15),
#   'Tweet': 'hallo ka, silahkan akses kembali (byDA)'},
#  {'Pengguna': 'Cute_Tagar',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 52, 12),
#   'Tweet': 'Tahun 1900an orang2 udah pakai Bom Atom, Senapan, Meriam. Tau-tau tahun 2022 NII diduga ingin lengserkan Pemerintah dengan Bukti Golok. Jarak Padang - Jakarta itu 1000Km lebih. Kira2 ini ya, sesakti apa Goloknya tuhhh??? https://t.co/xvBBjA3GJR'},
#  {'Pengguna': 'Hariss_FZ',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 52, 8),
#   'Tweet': 'RT : Tadi sore penyair Taufiq Ismail ke \u2066 \u2069 . Sekalian melihat kaset ceramah ayahanda beliau KH A Gaffar Ismail. KH…'},
#  {'Pengguna': 'DolfieOtay',
#   'Sentimen': 'Positif',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 52, 7),
#   'Tweet': 'RT _idha: Era Anies Baswedan, Layanan Administrasi Kependudukan di Jakarta Selesai dalam 15 Menit Amazing ini mah 👍😊 https://t.co/…'},
#  {'Pengguna': 'papicili02',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 52, 4),
#   'Tweet': 'RT : terapi itu gk mnggunakan obat,oles ( kapsul) ya dear,ckup di cari urat saraf ke arah mr p saja,yuk yg minat lngsung wa.081380…'},
#  {'Pengguna': 'Ttgs250',
#   'Sentimen': 'Positif',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 52, 3),
#   'Tweet': 'RT : available now untuk jakarta dan luar jawa 📲 083819489833 📍Jateng pemalang https://t.co/gWccJ98e8L https://t.co/Pj3CnH…'},
#  {'Pengguna': 'FabEmMiaw',
#   'Sentimen': 'Positif',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 52, 2),
#   'Tweet': 'Guys aku mau jual tas nih... Baru 1x pake banget. Bentuknya kayak di bawah ini. Real picture nya nyusul yaaa. Kirim dr Jakarta. Aku beli waktu itu harganya 200rb. Aku jual 120rb. Ongkir aku yg tanggung kalau nggak nego. Pembeli serius DM aja yak. Nanti lanjut WA. https://t.co/6JgYpKXi1B'},
#  {'Pengguna': 'UT_Jakarta',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 51, 58),
#   'Tweet': 'hallo ka, cantumkan nimnya dahulu yaa (byDA)'},
#  {'Pengguna': 'svytd',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 51, 58),
#   'Tweet': 'RT : David Da Silva, Persib, Barito Putera, dan PSSI Resmi digugat ke Pengadilan Negeri Jakarta Pusat atas dugaan sepakbola…'},
#  {'Pengguna': 'papicili02',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 51, 57),
#   'Tweet': 'RT : terapi itu gk mnggunakan obat,oles ( kapsul) ya dear,ckup di cari urat saraf ke arah mr p saja,yuk yg minat lngsung wa.08138…'},
#  {'Pengguna': 'anyeongjuseyo',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 51,

#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 50, 42),
#   'Tweet': 'RT : Goodbener mengajak kita semua warga DKI Jakarta untuk menggapai keberkahan Allah dengan serentak membaca Alq…'},
#  {'Pengguna': 'antika56893672',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 50, 40),
#   'Tweet': 'Gabener seenak jidat, gak punya tggjwb\U0001fae2 udh gitu mo nyapres pula🤣 Sebelumnya Pras mengatakan sudah seharusnya Gubernur DKI Jakarta Anies Baswedan menjelaskan kesiapan perhelatan Formula E kepada publik. https://t.co/vM0KNgq1UW'},
#  {'Pengguna': 'sellkpopfess',
#   'Sentimen': 'Positif',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 50, 39),
#   'Tweet': 'Kuy- 🎀CIAO NCTZEN🎀 Mau j0in G0 NCT WAYV yg trusted, rate rendah, &amp; admin ramah?? DISINI TEMPATNYAA!!💗💫 Rate cuma 🇰🇷12.2 &amp; 🇨🇳2320 😼👍🏻 📍Jakarta timur 👥300++ member aktif!💖 ✅Can personal order &amp; many testi! Link di rep https://t.co/PNlaG1A4RO'},
#  {'Pengguna': 'KPU_Enrekang',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 50, 35),
#   'Tweet': "RT _ID: #Temanpemilih, Ketua KPU RI Hasyim Asy'ari bersama Anggota KPU RI M. Afifuddin menghadiri peringatan Hari lahir Organisasi Perg…"},
#  {'Pengguna': 'Desri24428503',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 50, 34),
#   'Tweet': '_warsono Dia sdg berupaya mengalihkan kesalahannya sbg Gub DKI ke Pemerintah Pusat.! Gub. Dungu.! Program Normalisasi Sungai adalah solusi utama mengatasi banjir Jakarta, namun dia tolak selama ini. Skrg saat mau lengser dr jabatan, dia bertindak seolah Pusat yg Salah.! 👎👎'},
#  {'Pengguna': 'mcngdgn',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 50, 29),
#   'Tweet': 'RT : INVESTIGASI TERBARU Setelah enam bulan melakukan investigasi, kami mempublikasikan tulisan ini. Saya menginvestigasi ribuan…'},
#  {'Pengguna': 'Sammongis',
#   'Sentimen': 'Positif',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 50, 26),
#   'Tweet': 'RT _Halona: Pegal? Lesu? Butuh pijat traditional plus BO dan berada di Kota #Jakarta? TENDEAN NOW ready now start 14.00-24.00 Hubu…'},
#  {'Pengguna': 'KemenkopUKM',
#   'Sentimen': 'Negatif',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 50, 24),
#   'Tweet': 'Yuk, persiapkan usaha Sobat UMKM dan Asosiasi untuk ikut serta dalam Temu Bisnis Pengadaan Barang/Jasa Pemerintah! Catat waktu dan tempatnya ya.. Tanggal: 22 - 23 April 2022 Lokasi: Balai Sidang Jakarta Convention Center #KemenKopUKM #UMKMBangkit #KoperasiModern #IndonesiaMaju https://t.co/jm4hKkqF4R'},
#  {'Pengguna': 'T_Irham',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 50, 23),
#   'Tweet': '6# Pemerintah pusat melalui PT Sarana Multi Infrastruktur (Persero) telah mencairkan dana PEN kepada DKI Jakarta sebesar Rp12,5 triliun pada 2020 lalu. Dana sebanyak Rp5,297 triliun dialokasikan untuk penanggulangan banjir yang dikerjakan selama tiga tahun dari 2020-2022.'},
#  {'Pengguna': 'Generasi1997',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 50, 22),
#   'Tweet': 'RT : Hingga saat ini program ramadhan berbagi Front Persaudaraan Islam (FPI) telah mendistribusikan 5500 box lebih nasi kebuli, mand…'},
#  {'Pengguna': 'elghufron',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 50,

#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 49, 41),
#   'Tweet': 'RT _org: Orang Jakarta mungkin tidak tahu bahwa kota ini sedang mengalami kehilangan besar. Jakarta kehilangan Rasdullah, pemimpin…'},
#  {'Pengguna': 'T_Irham',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 49, 34),
#   'Tweet': '5# "Selalu mengerjakan program yang nyeleneh dan tidak tepat sasaran, alhasil menjelang jabatan sebagai Gubernur Jakarta akan berakhir, Pak Anies malah kelabakan seperti ini," kata Anggota Komisi D DPRD DKI Jakarta itu.'},
#  {'Pengguna': 'KantahKabPkl',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 49, 32),
#   'Tweet': '#Repost _bpn Memasuki hari ke-15 di bulan Ramadan, Menteri Agraria dan Tata Ruang/Kepala Badan Pertanahan Nasional (ATR/BPN), Sofyan A. Djalil melakukan silaturahmi dengan Masyarakat Aceh Jakarta di Wisma Taman Iskandar Muda Jakarta~ https://t.co/JIG0aZ4Afw'},
#  {'Pengguna': 'nadrayanti',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 49, 27),
#   'Tweet': 'RT : Hingga saat ini program ramadhan berbagi Front Persaudaraan Islam (FPI) telah mendistribusikan 5500 box lebih nasi kebuli, mand…'},
#  {'Pengguna': 'SondangNapitup6',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 49, 13),
#   'Tweet': 'Semakin dekat dengan Anda untuk memberikan layanan purna jual, Fingerspot hadir diberbagai lokasi : ✅Jakarta ✅Bandung ✅Bekasi ✅Surabaya ✅Malang ✅Yogyakarta ✅Purwokerto ✅Semarang ✅Solo ✅Denpasar ✅Medan ✅Balikpapan ✅Banjarmasin ✅ Pontianak https://t.co/jqHWyeFvO8'},
#  {'Pengguna': 'ZupersoepriE',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 49, 9),
#   'Tweet': 'RT : Hingga saat ini program ramadhan berbagi Front Persaudaraan Islam (FPI) telah mendistribusikan 5500 box lebih nasi kebuli, mand…'},
#  {'Pengguna': 'JhoniNadeak23',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 49, 3),
#   'Tweet': 'RT : Teroris Sumbar bersenjatakan golok sudah memasuki jakarta, mau gulingkan kekuasaan Jokowi. 😆😆😆 Drama anak negeri kian luc…'},
#  {'Pengguna': 'kotaurban',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 49, 3),
#   'Tweet': 'RT : Terjadi kebakaran pd Apartemen Palazo pkl. 10.20 di Jl. Apron Kel. Kebon Kosong, Kec. Kemayoran (titik kenal Polsek Kemay…'},
#  {'Pengguna': 'perpusuinjkt',
#   'Sentimen': 'Negatif',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 49, 2),
#   'Tweet': 'PENGARUH DISIPLIN KERJA DAN STRES KERJA TERHADAP KINERJA DENGAN MOTIVASI KERJA SEBAGAI VARIABEL INTERVENING (Studi Pada Karyawan Balai Sidang Jakarta Convention Center) https://t.co/X1qaSF9Nld'},
#  {'Pengguna': 'IyanMB95',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 48, 58),
#   'Tweet': 'RT : Jakarta 🏡 grogol Selamat pagi 😍 Wa/tele 083872610846 #BOjakarta #pijatdepok #Pijatjakarta #pijatsensual #PijatJakSel #Pi…'},
#  {'Pengguna': 'Kurniaw53369919',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 48, 56),
#   'Tweet': 'Berkabar ya kalau mau ke jakarta, Arep tak cubit cangkem e.'},
#  {'Pengguna': 'JEMBUTNYABIRU',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 48, 55),
#   'Tweet': 'SAKING OTAK NYA GA MAMPU DAN GA PUNYA GAGASAN AKHIRNYA NGIBUL NGARANG CERITA PERMUKAAN TANAH JAKARTA UDAH NAEK BUKA DATA 😂😂😂😂😂 DI URUG KAGA DI TIMBUN KAGA, KOK BISA NAEK PERMUKAAN TANAHNYA ? YANG NAEKIN PERMUKAAN TANAHNYA JIN APA TUYUL ANCOL ? 😂😂😂😂😂'},
#  {'Pengguna': 'RumahJualbeli',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 48, 55),
#   'Tweet': 'CARI TANAH KAVLING UNTUK BANGUN KEBUN BUAH? TERJANGKAU, Hubungi 0812-1244-2489, Kavling Tanah Dijual Murah Di Kavling Desa Wisata Kebun Buah Saung Estetik Dekat Jakarta https://t.co/b6NZX2PgZP'},
#  {'Pengguna': 'nabilmachmoed',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 48, 54),
#   'Tweet': 'RT : . 19 March 2023 // Jakarta, Indonesia Tickets + Info: https://t.co/YmE1Cl8Dis https://t.co/lKgT35dAfJ'},
#  {'Pengguna': 'T_Irham',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 48, 54),
#   'Tweet': '4# Kenneth mengatakan, pemerintah pusat selalu mencoba menjalin komunikasi atau kolaborasi dalam membenahi permasalahan di Jakarta selama Anies menjabat. Namun, program yang dibuat Anies kerap kali tidak sejalan.'},
#  {'Pengguna': 'Jakamaulana19',
#   'Sentimen': 'Netral',
#   'Tanggal': datetime.datetime(2022, 4, 19, 3, 48, 53),
#   'Tweet': 'Saya seorang petugas penunjang medis di RSUD d Jakarta, anak saya sakit bawa ke UGD sampai di rawat, urusan administrasi, ambil obat, anter urine, Foto copy yg diperlukan urus sendiri. Kan anak kita yg sakit, petugas juga terbatas , berkorban lah.'}]

# %% [markdown]
# ## Converting Search Result to Pandas Dataframe

# %%
df = pd.DataFrame(data_search)
df
# Out:
#                Tanggal        Pengguna  \
# 0  2022-04-19 03:54:47  rumah_jualbeli
# 1  2022-04-19 03:54:42         salbi__
# 2  2022-04-19 03:54:26        dwijlynt
# 3  2022-04-19 03:54:26   setyawarni123
# 4  2022-04-19 03:54:20         T_Irham
# ..                 ...             ...
# 95 2022-04-19 03:48:55   JEMBUTNYABIRU
# 96 2022-04-19 03:48:55   RumahJualbeli
# 97 2022-04-19 03:48:54   nabilmachmoed
# 98 2022-04-19 03:48:54         T_Irham
# 99 2022-04-19 03:48:53   Jakamaulana19
#
#                                                 Tweet Sentimen
# 0   TERJANGKAU, Hubungi 0812-1244-2489, Kavling Ta...   Netral
# 1              akwowakoawkaow kos gawe di jakarta wae   Netral
# 2   Damage nya ga parah banget nih nder , take all...   Netral
# 3   RT : Goodbener mengajak kita semua warga DKI J...   Netral
# 4   10# Berikut delapan dukungan yang disampaikan ...   Netral
# ..                                                ...      ...
# 95  SAKING OTAK NYA GA MAMPU DAN GA PUNYA GAGASAN ...   Netral
# 96  CARI TANAH KAVLING UNTUK BANGUN KEBUN BUAH? TE...   Netral
# 97  RT : . 19 March 2023 // Jakarta, Indonesia Tic...   Netral
# 98  4# Kenneth mengatakan, pemerintah pusat selalu...   Netral
# 99  Saya seorang petugas penunjang medis di RSUD d...   Netral
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Saving Pandas Dataframe to CSV File

# %%
df.to_csv('data_search.csv')
